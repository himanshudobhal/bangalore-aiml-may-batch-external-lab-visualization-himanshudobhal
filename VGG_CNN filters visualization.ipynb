# %% [markdown]
# ##  Visualization of the Filters

# %% [markdown]
# ### Import tensorflow and load the VGG19 model with weights pre-trained on Imagenet.

# %%
import tensorflow as tf
model=tf.keras.applications.vgg19.VGG19(weights='imagenet')

# %% [markdown]
# ### Check model summary to see layer names and no.of filters in each layer

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Load given image

# %%
image=tf.keras.preprocessing.image.load_img('dog-1.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=525x350 at 0x7FA8E3C2FA58>

# %% [markdown]
# ### Get model Input

# %%
import matplotlib.pyplot as plt
import numpy as np

img_array = np.random.random((1, 128, 128,3))
img_array = (img_array - 0.5) * 20 + 128
input_img = model.input

# %% [markdown]
# ### Get model output of layer with name `block1_conv1`

# %%
layer_name = 'block5_conv1'
model_output = model.get_layer(layer_name).output
model_output
# Out:
# <tf.Tensor 'block5_conv1/Relu:0' shape=(?, 14, 14, 512) dtype=float32>

# %% [markdown]
# ### Calculate Gradient for multiple filters

# %%
filters_info = []
K = tf.keras.backend

for i in range(64):
    
    print('Processing filter ', i , ' of layer ', layer_name)
    loss = K.mean(model_output[:,:,:,i])  
    grads = K.gradients(loss, input_img)[0]
    grads /= K.sqrt(K.mean(K.square(grads))) + K.epsilon()
    iterate = K.function([input_img], [loss, grads])
    updated_img_input = img_array.copy()
    for j in range(40):
        loss_value, grads_value = iterate([updated_img_input])
        updated_img_input += grads_value
        if loss_value < 0:
            break
            
    if loss_value > 0:
        filters_info.append((i, updated_img_input[0]))
# Out:
# Processing filter  0  of layer  block5_conv1
# Processing filter  1  of layer  block5_conv1
# Processing filter  2  of layer  block5_conv1
# Processing filter  3  of layer  block5_conv1
# Processing filter  4  of layer  block5_conv1
# Processing filter  5  of layer  block5_conv1
# Processing filter  6  of layer  block5_conv1
# Processing filter  7  of layer  block5_conv1
# Processing filter  8  of layer  block5_conv1
# Processing filter  9  of layer  block5_conv1
# Processing filter  10  of layer  block5_conv1
# Processing filter  11  of layer  block5_conv1
# Processing filter  12  of layer  block5_conv1
# Processing filter  13  of layer  block5_conv1
# Processing filter  14  of layer  block5_conv1
# Processing filter  15  of layer  block5_conv1
# Processing filter  16  of layer  block5_conv1
# Processing filter  17  of layer  block5_conv1
# Processing filter  18  of layer  block5_conv1
# Processing filter  19  of layer  block5_conv1
# Processing filter  20  of layer  block5_conv1
# Processing filter  21  of layer  block5_conv1
# Processing filter  22  of layer  block5_conv1
# Processing filter  23  of layer  block5_conv1
# Processing filter  24  of layer  block5_conv1
# Processing filter  25  of layer  block5_conv1
# Processing filter  26  of layer  block5_conv1
# Processing filter  27  of layer  block5_conv1
# Processing filter  28  of layer  block5_conv1
# Processing filter  29  of layer  block5_conv1
# Processing filter  30  of layer  block5_conv1
# Processing filter  31  of layer  block5_conv1
# Processing filter  32  of layer  block5_conv1
# Processing filter  33  of layer  block5_conv1
# Processing filter  34  of layer  block5_conv1
# Processing filter  35  of layer  block5_conv1
# Processing filter  36  of layer  block5_conv1
# Processing filter  37  of layer  block5_conv1
# Processing filter  38  of layer  block5_conv1
# Processing filter  39  of layer  block5_conv1
# Processing filter  40  of layer  block5_conv1
# Processing filter  41  of layer  block5_conv1
# Processing filter  42  of layer  block5_conv1
# Processing filter  43  of layer  block5_conv1
# Processing filter  44  of layer  block5_conv1
# Processing filter  45  of layer  block5_conv1
# Processing filter  46  of layer  block5_conv1
# Processing filter  47  of layer  block5_conv1
# Processing filter  48  of layer  block5_conv1
# Processing filter  49  of layer  block5_conv1
# Processing filter  50  of layer  block5_conv1
# Processing filter  51  of layer  block5_conv1
# Processing filter  52  of layer  block5_conv1
# Processing filter  53  of layer  block5_conv1
# Processing filter  54  of layer  block5_conv1
# Processing filter  55  of layer  block5_conv1
# Processing filter  56  of layer  block5_conv1
# Processing filter  57  of layer  block5_conv1
# Processing filter  58  of layer  block5_conv1
# Processing filter  59  of layer  block5_conv1
# Processing filter  60  of layer  block5_conv1
# Processing filter  61  of layer  block5_conv1
# Processing filter  62  of layer  block5_conv1
# Processing filter  63  of layer  block5_conv1

# %%
len(filters_info)
# Out:
# 47

# %% [markdown]
# ### Plot Images for each filter

# %%
filters_info.sort(key=lambda x: x[0], reverse=True)
filters_info = filters_info[:36]

# %% [markdown]
# ### Deprocess image

# %%
def deprocess_image(x):
    
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + K.epsilon())
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = np.clip(x, 0, 255).astype('uint8')
    
    return x

# %% [markdown]
# ### Plot image of 4th filter

# %%
plt.figure(figsize=(8,8))
plt.imshow(deprocess_image(filters_info[4][1]))
plt.show()

# %% [markdown]
# ### Plot all the images of 64 filters

# %%
plt.subplots(6,6, figsize=(12,12))

for i in range(len(filters_info)):
    
    plt.subplot(6,6,i+1)
    plt.axis('off')
    img_updated = deprocess_image(filters_info[i][1])
    plt.imshow(img_updated, cmap='jet')

plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# First layer distinguish colours.
#
# Some of the first images seem to have duplicated infomation (same colour). So maybe we can reduce the number of featuremap while keeping the same model performance.
